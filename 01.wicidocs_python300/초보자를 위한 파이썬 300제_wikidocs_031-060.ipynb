# %%
a = "3"
b = "4"
print(a + b)
# Out:
# 34

# %%
print("Hi" * 3)
# Out:
# HiHiHi

# %%
print("-" * 80)
# Out:
# --------------------------------------------------------------------------------

# %%
t1 = 'python'
t2 = 'java'

# %%
print(t1, t2, t1, t2, t1, t2)
# Out:
# python java python java python java

# %%
name1 = "김민수"
age1 = 10
name2 = "이철희"
age2 = 13

# %%
print("이름 : ",name1 ,"나이 :" , age1)
print("이름 : ",name2 ,"나이 :" , age2)
# Out:
# 이름 :  김민수 나이 : 10
# 이름 :  이철희 나이 : 13

# %%
print("이름 : %s 나이 : %d" % (name1, age1))
print("이름 : %s 나이 : %d" % (name2, age2))
# Out:
# 이름 : 김민수 나이 : 10
# 이름 : 이철희 나이 : 13

# %%
print("이름 : {} 나이 : {}".format(name1, age1))
print("이름 : {} 나이 : {}".format(name2, age2))
# Out:
# 이름 : 김민수 나이 : 10
# 이름 : 이철희 나이 : 13

# %%
print(f"이름 : {name1} 나이 : {age1}")
print(f"이름 : {name2} 나이 : {age2}")
# Out:
# 이름 : 김민수 나이 : 10
# 이름 : 이철희 나이 : 13

# %%
상장주식수 = "5,969,782,550"

# %%
a = 상장주식수.replace(",","")
b = int(a)
print(b,type(b))
# Out:
# 5969782550 <class 'int'>

# %%
분기 = "2020/03(E) (IFRS연결)"

# %%
print(분기[:7])
# Out:
# 2020/03

# %%
data = "       삼성전자      "

# %%
print(data.strip())
# Out:
# 삼성전자

# %%
ticker = "btc_krw"

# %%
ticker_1 = ticker.upper()
print(ticker_1)
# Out:
# BTC_KRW

# %%
print(ticker_1.lower())
# Out:
# btc_krw

# %%
a = "hello"
a = a.capitalize()
print(a)
# Out:
# Hello

# %%
file_name = "보고서.xlsx"

# %%
file_name.endswith("서.xlsx")
# Out:
# True

# %%
file_name = "보고서.xlsx"

# %%
file_name.endswith(("xls","xlsx"))
# Out:
# True

# %%
file_name = "2020_보고서.xlsx"

# %%
file_name.startswith("2020")
# Out:
# True

# %%
a = "hello world"

# %%
a.split(" ")
# Out:
# ['hello', 'world']

# %%
a.split()
# Out:
# ['hello', 'world']

# %%
ticker = "btc_krw"

# %%
ticker.split("_")
# Out:
# ['btc', 'krw']

# %%
date = "2020-05-01"

# %%
date.split("-")
# Out:
# ['2020', '05', '01']

# %%
data = "039490      "

# %%
data.rstrip()
# Out:
# '039490'

# %%
movie_rank = ["닥터 스트레인지", "스플릿", "럭키"]
movie_rank
# Out:
# ['닥터 스트레인지', '스플릿', '럭키']

# %%
movie_rank.append("배트맨")
movie_rank
# Out:
# ['닥터 스트레인지', '스플릿', '럭키', '배트맨']

# %%
movie_rank.insert(1,"슈퍼맨")
movie_rank
# Out:
# ['닥터 스트레인지', '슈퍼맨', '스플릿', '럭키', '배트맨']

# %%
movie_rank.pop(3)
movie_rank
# Out:
# ['닥터 스트레인지', '슈퍼맨', '스플릿', '배트맨']

# %%
movie_rank.pop(2)
movie_rank.pop(2)
movie_rank #del 써도 됨. pop은 해당 인덱스 값을 반환함
# Out:
# ['닥터 스트레인지', '슈퍼맨']

# %%
nums = [1, 2, 3, 4, 5, 6, 7]

# %%
print("max: ",max(nums))
print("min: ",min(nums))
# Out:
# max:  7
# min:  1

# %%
sum(nums)
# Out:
# 28

# %%
cook = ["피자","김밥","만두","양념치킨","족발","피자","김치만두","쫄면","소시지","라면","팥빙수","김치전"]

# %%
len(cook)
# Out:
# 12

# %%
nums = [1, 2, 3, 4, 5]

# %%
sum(nums) / len(nums)
# Out:
# 3.0

# %%
average = sum(nums) / len(nums)
print(average)
# Out:
# 3.0
