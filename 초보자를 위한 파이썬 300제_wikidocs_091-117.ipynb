# %%
inventory = {'메로나':[300,20],
             '비비빅':[400,3],
             '죠스바':[250,100]} 
inventory
# Out:
# {'메로나': [300, 20], '비비빅': [400, 3], '죠스바': [250, 100]}

# %%
print(inventory['메로나'][0],'원')
# Out:
# 300 원

# %%
print(inventory['메로나'][1],'개')
# Out:
# 20 개

# %%
inventory['월드콘'] = [500,7]
inventory
# Out:
# {'메로나': [300, 20], '비비빅': [400, 3], '죠스바': [250, 100], '월드콘': [500, 7]}

# %%
icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}

# %%
price = list(icecream.values())
print(price)
# Out:
# [1200, 1200, 1800, 1500, 1000]

# %%
#sum(list(icecream.values()))
print(sum(icecream.values()))
# Out:
# 6700

# %%
icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
new_product = {'팥빙수':2700, '아맛나':1000}

# %%
icecream.update(new_product)
print(icecream)
# Out:
# {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000, '팥빙수': 2700, '아맛나': 1000}

# %%
keys = ("apple", "pear", "peach")
vals = (300, 250, 400)

# %%
result =dict(zip(keys,vals))
print(result)
# Out:
# {'apple': 300, 'pear': 250, 'peach': 400}

# %%
date = ['09/05', '09/06', '09/07', '09/08', '09/09']
close_price = [10500, 10300, 10100, 10800, 11000]

# %%
close_table = dict(zip(date,close_price))
print(close_table)
# Out:
# {'09/05': 10500, '09/06': 10300, '09/07': 10100, '09/08': 10800, '09/09': 11000}

# %%
#boolean, Ture or False

# %%
print(3 == 5)
"False"
# Out:
# False
# 'False'

# %%
print(3<5)
"True"
# Out:
# True
# 'True'

# %%
x = 4
print(1 < x < 5)
"True"
# Out:
# True
# 'True'

# %%
print((3 == 3) and (4 != 3))
"True"
# Out:
# True
# 'True'

# %%
#print(3 => 4)
"에러의 원인은 연산자 표기오류, 원하는대로 False 이려면 >= 이어야 함"
print(3 >= 4)
# Out:
# False

# %%
if 4 <3 :
    print("hello world")

else: print('None')
"None?xx 조건을 만족하지 않으므로 아무것도 출력되지 않는다. None 출력하려면, ""else: print('None')"" 추가"
# Out:
# None
# "None?xx 조건을 만족하지 않으므로 아무것도 출력되지 않는다. None 출력하려면, else: print('None') 추가"

# %%
if 4 < 3:
    print("Hello World.")
else:
    print("Hi, there.")
"hi,there. 출력됨"
# Out:
# Hi, there.
# 'hi,there. 출력됨'

# %%
if True :
    print ("1")
    print ("2")
else :
    print("3")
print("4")
"1,2,4: True가 기본값인갑다"
# Out:
# 1
# 2
# 4
# '1,2,4: True가 기본값인갑다'

# %%
if True :
    if False:
        print("1")
        print("2")
    else:
        print("3")
else :
    print("4")
print("5")
"3,5"
# Out:
# 3
# 5
# '3,5'

# %%
user = input("입력")
print(user*2)
# Out:
# 입력 안녕하세요
# 안녕하세요안녕하세요

# %%
user = input("숫자를 입력하세요: ")
print(int(user) + 10) #인풋 디폴트값이 str 인가바
# Out:
# 숫자를 입력하세요:  30
# 40

# %%
user = input("숫자를 입력하세요 : ")
if int(user) % 2 == 0:
    print("짝수")
else:
    print("홀수")
# Out:
# 숫자를 입력하세요 :  4
# 짝수

# %%
user = input("입력값 : ")
if int(user) + 20 > 255 :
    print("출력값 : 255")
else:
    print("출력값 : ",int(user)+20)
# Out:
# 입력값 :  30
# 출력값 :  50

# %%
user = input("입력값 : ")
num = 20 + int(user)
if num > 255 :
    print("출력값 : 255")
else:
    print("출력값 : ",num)
# Out:
# 입력값 :  11
# 출력값 :  31

# %%
user = input("입력값 : ")
num =  int(user) - 20
if num > 255 :
    print("출력값 : 255")
elif num < 0 :
    print("출력값 : 0")
else:
    print("출력값 : ",num)
# Out:
# 입력값 :  44
# 출력값 :  24

# %%
time = input("현재 시간 >>")
print(time[-2:])
# Out:
# 현재 시간 >> 5:50
# 50

# %%
time = input("현재시간: ")
if time[-2:] == "00":
    print("정각 입니다.")
else:
    print("정각이 아닙니다.")
# Out:
# 현재시간:  4:00
# 정각 입니다.

# %%
fruit = ["사과", "포도", "홍시"]
user = input("좋아하는 과일은? :")
if user in fruit :
    print("정답입니다")
else:
    print("오답입니다")
# Out:
# 좋아하는 과일은? : 감자
# 오답입니다
