# %%
def print_coin():
    print("비트코인")
print_coin()
# Out:
# 비트코인

# %%
for i in range(100):
    print_coin()
# Out:
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인

# %%
def print_coins():
    for i in range(100):
        print("비트코인")
print_coins()
# Out:
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인
# 비트코인

# %%
hello()
def hello():
    print("Hi")
#함수를 함수지정하기 전에 써버렸다. 에러는 헬로 라고 정의된 함수는 없다는 내용
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 hello()
#       2 def hello():
#       3     print("Hi")
#
# NameError: name 'hello' is not defined

# %%
def message() :
    print("A")
    print("B")

message()
print("C")
message()

# A 
# B 
# C
# A 
# B
# Out:
# A
# B
# C
# A
# B

# %%
print("A")

def message() :
    print("B")

print("C")
message()

# A
# C
# B
# Out:
# A
# C
# B

# %%
print("A")
def message1() :
    print("B")
print("C")
def message2() :
    print("D")
message1()
print("E")
message2()

# A
# C
# B
# E
# D
# Out:
# A
# C
# B
# E
# D

# %%
def message1():
    print("A")

def message2():
    print("B")
    message1()

message2()

# B
# A
# Out:
# B
# A

# %%
def message1():
    print("A")

def message2():
    print("B")

def message3():
    for i in range (3) :
        message2()
        print("C")
    message1()

message3()

# B
# C
# B
# C
# B
# C
# A
# Out:
# B
# C
# B
# C
# B
# C
# A

# %%
def 함수(문자열) :
    print(문자열)

함수("안녕")
함수("Hi")

# 안녕
# Hi
# Out:
# 안녕
# Hi

# %%
def 함수(a, b) :
    print(a + b)

함수(3, 4)
함수(7, 8)

# 7
# 15
# Out:
# 7
# 15

# %%
def 함수(문자열) :
    print(문자열)
함수()  #문자열을 포함해서 수행하는 함수인데 함수가 들어가있지 않다
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 def 함수(문자열) :
#       2     print(문자열)
# ----> 3 함수()  #문자열을 포함해서 수행하는 함수인데 함수가 들어가있지 않다
#
# TypeError: 함수() missing 1 required positional argument: '문자열'

# %%
def 함수(a, b) :
    print(a + b)

함수("안녕", 3)

#더할 수 있는, 정수나 실수형태의 파라미터가 입력되어야 하는데 서로다른 파라미터가 입력되었고 더할 수 없는 문자열과 정수이다
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 4
#       1 def 함수(a, b) :
#       2     print(a + b)
# ----> 4 함수("안녕", 3)
#       6 #더할 수 있는, 정수나 실수형태의 파라미터가 입력되어야 하는데 서로다른 파라미터가 입력되었고 더할 수 없는 문자열과 정수이다
#
# Cell In[27], line 2, in 함수(a, b)
#       1 def 함수(a, b) :
# ----> 2     print(a + b)
#
# TypeError: can only concatenate str (not "int") to str

# %%
def print_with_smile(문자열):
    print(문자열,":D")

print_with_smile("하이하이")
print_with_smile(99999)
print_with_smile("안녕하세요")
# Out:
# 하이하이 :D
# 99999 :D
# 안녕하세요 :D

# %%
def print_upper_price():
    user = input(int)
    print(int(user) * 1.3)
print_upper_price()
# Out:
# 6552.0

# %%
def print_upper_price(price):

    print(price* 1.3)
print_upper_price(5540)
# Out:
# 7202.0

# %%
def print_sum(a,b):
    print(a + b)
print_sum(880,5756)
# Out:
# 6636

# %%
def print_arithmetic_operation(a,b):
    print(a, "+", b,"=", a +b)
    print(a, "-",b,"=", a -b)
    print(a, "*", b,"=", a *b)
    print(a, "/", b,"=", a /b)
print_arithmetic_operation(3, 4)
# Out:
# 3 + 4 = 7
# 3 - 4 = -1
# 3 * 4 = 12
# 3 / 4 = 0.75

# %%
def print_max(a,b,c):
    if a > b and a > c :
        print("max",a)
    elif b > a and b> c :
        print("max", b)
    elif c > a and c > b:
        print("max", c)
print_max(888,8889,44552)
max(888,8889,44552)
# Out:
# max 44552
# 44552
